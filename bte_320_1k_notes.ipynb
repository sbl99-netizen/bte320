# %% [markdown]
# <a href="https://colab.research.google.com/github/sbl99-netizen/bte320/blob/main/bte_320_1k_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hey")
# Out:
# Hey

# %% [markdown]
# test

# %%
x = 2
print(x)
# Out:
# 2

# %% [markdown]
# another test
